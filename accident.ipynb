# %% [markdown]
# <a href="https://colab.research.google.com/github/terrymosigo/Paimosi-website/blob/main/accident.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
newdata=pd.read_csv('/content/newdata.csv')
newdata.head(10)
# Out:
#            Employee  Gender                 Department  salary
# 0    Emily Johnson   Female  Human Resource Department    6747
# 1    Benjamin Smith    male       Marketing Department    1011
# 2  Sophia Williams   Female         Finance Department    2109
# 3    William brown     male              IT Department    1260
# 4     olivia Davis   Female           Sales Department    2583
# 5      james wilson    male  Human Resource Department    8284
# 6     Ava Martinez   Female       Marketing Department    3989
# 7     Liam Anderson    male         Finance Department    7316
# 8      Mia Thompson  Female              IT Department    7625
# 9  Ethan Rodriguez     male           Sales Department    7054

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Accident.csv')
print("shape of dataset:", data.shape)
data.head(16)
# Out:
# shape of dataset: (14, 6)
#      County no   year                  Road           cause  number of cases  \
# 0            47  2022           Waiyaki way        Alcohol                 3
# 1            32  2022         kiratina Road     faulty road                5
# 2            33  2022           olerai road  breaks failure               14
# 3            35  2022             Londiani   breaks failure                2
# 4             1  2022            Moi avenue    bad weather                16
# 5            36  2022           tenwek road     faulty road               13
# 6            22  2022           thika road     overspeeding                7
# 7            45  2022  kisii-migori highway        Alcohol                 6
# 8            46  2022            corner Tee     faulty road               11
# 9            14  2022        jacaranda road    bad weather                 9
# 10           44  2022           opapo road   breaks failure                4
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# load dataset
data= pd.read_csv('/content/drive/MyDrive/Accident.csv')
#split the data into features (x) and labels (y)
x = data.drop('number of cases', axis=1)
y = data['number of casualities']
#split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# load dataset
data= pd.read_csv('/content/drive/MyDrive/Accident.csv')
#split the data into features (x) and labels (y)
x = data.drop('number of cases', axis=1)
y = data['number of casualities']
#split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)
geo= DecisionTreeClassifier(criterion='entropy', random_state=0)
geo.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c594c3529674> in <cell line: 13>()
#      11 x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)
#      12 geo= DecisionTreeClassifier(criterion='entropy', random_state=0)
# ---> 13 geo.fit(x_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     887         """
#     888
# --> 889         super().fit(
#     890             X,
#     891             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     184             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186             X, y = self._validate_data(
# ...

# %%
model=LinearRegression()

# %%
geo = DecisionTreeClassifier (criterion='entropy', random_state=42)
geo.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1bf40764bc7b> in <cell line: 1>()
# ----> 1 geo = DecisionTreeClassifier (criterion='entropy', random_state=42)
#       2 geo.fit(x_train,y_train)
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %%
from google.colab import drive

# %%
import pandas as pd
newdata=pd.read_csv('/.csv')
newdata.head(10)

# %%
import pandas as pd
newdata=pd.read_csv('/content/newdata.csv')
newdata.head(10)
DepartmentDuplicate=newdata[newdata['Department'].duplicated()]
print("Duplicate Department")
print(DepartmentDuplicate)
# Out:
# Duplicate Department
#             Employee  Gender                 Department  salary
# 5       james wilson    male  Human Resource Department    8284
# 6      Ava Martinez   Female       Marketing Department    3989
# 7      Liam Anderson    male         Finance Department    7316
# 8       Mia Thompson  Female              IT Department    7625
# 9   Ethan Rodriguez     male           Sales Department    7054
# 10    isabell Garcia  Female  Human Resource Department    4522
# 11    Noah Martinez     male       Marketing Department    2028
# 12     Emman Johnson  Female         Finance Department    8770

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
Data= pd.read_csv('/content/drive/MyDrive/Accident.csv')
print("shape of dataset:", Data.shape)
Data.head()
# Out:
# shape of dataset: (14, 6)
#    County   year           Road           cause  number of cases  \
# 0  Nairobi  2022    Waiyaki way        Alcohol                 3
# 1  nakuru   2022  kiratina Road     faulty road                5
# 2    Narok  2022    olerai road  breaks failure               14
# 3  Kericho  2022      Londiani   breaks failure                2
# 4  Mombasa  2022     Moi avenue    bad weather                16
#
#    number of casualities
# 0                     60
# 1                    100
# 2                     10
# 3                    200
# 4                     50

# %%
import pandas as pd
Data= pd.read_csv('/content/drive/MyDrive/Accident.csv')
data=Data.loc[:,['number of cases','number of casualities']]
Data.head(5)
# Out:
#    County   year           Road           cause  number of cases  \
# 0  Nairobi  2022    Waiyaki way        Alcohol                 3
# 1  nakuru   2022  kiratina Road     faulty road                5
# 2    Narok  2022    olerai road  breaks failure               14
# 3  Kericho  2022      Londiani   breaks failure                2
# 4  Mombasa  2022     Moi avenue    bad weather                16
#
#    number of casualities
# 0                     60
# 1                    100
# 2                     10
# 3                    200
# 4                     50

# %%
import pandas as pd
Data= pd.read_csv('/content/drive/MyDrive/Accident.csv')
Data.plot(x='number of cases',y='number of casualities',style=0)
plt.xlbel('number of cases')
plt.ylabel('number of casualities')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a28c192dd66d> in <cell line: 3>()
#       1 import pandas as pd
#       2 Data= pd.read_csv('/content/drive/MyDrive/Accident.csv')
# ----> 3 Data.plot(x='number of cases',y='number of casualities',style=0)
#       4 plt.xlbel('number of cases')
#       5 plt.ylabel('number of casualities')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'county'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import  LinearRegression
#load dataset
Data= pd.read_csv('/content/drive/MyDrive/Accident.csv')
#Extract  the independent variable (x) and dependent variable (y)
x = Data[['number of cases']]
y = Data[['number of casualities']]
# Create a linear model
regressor =LinearRegression()
regressor.fit(x,y)
Data.plot(x='number of cases', y='number of casualities',label='Data points')
plt.plot(x, regressor.predict(x), color='red', linewidth=2, label='Regression Line')
plt.xlabel('number of cases')
plt.ylabel('number of casualities')
plt.legend()
plt.show()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-aeb196a31adb> in <cell line: 1>()
# ----> 1 y_pred = regressor.predict(x_test)
#       2 y_pred
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# ...

# %%
import joblib
import pickle
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(x,y)
joblib.dump(model, 'linear_regression_model.pkl')
with open('linear_regression_model.pkl', 'wb') as file:
  pickle.dump(model, file)
